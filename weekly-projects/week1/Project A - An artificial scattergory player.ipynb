# %%
# Homework 1 (due 6/28/2024)

# %%
import random

categories = [
    "Fruits",
    "Vegetables",
    "Animals",
    "Countries",
    "Cities",
    "Famous People",
    "Colors",
    "Sports",
    "Clothing",
    "Food",
    "Drinks",
    "Tools",
    "Flowers",
    "Movies",
    "Books",
    "Songs",
    "TV Shows",
    "Brands",
    "Transport",
    "Jobs"
]

def get_categories():
    print("Here are the available categories:")
    for i, category in enumerate(categories, 1):
        print(f"{i}. {category}")
    
    selected_categories = []
    while len(selected_categories) < 5:
        try:
            choice = int(input(f"Select category {len(selected_categories) + 1} (1-20): "))
            if 1 <= choice <= 20 and categories[choice - 1] not in selected_categories:
                selected_categories.append(categories[choice - 1])
            else:
                print("Invalid choice or category already selected.")
        except ValueError:
            print("Please enter a number between 1 and 20.")
    
    return selected_categories

def generate_answers(selected_categories, letter):
    
    #nested dictionaries of each category from A to Z
    #generated elements for each category using ChatGPT, some elements manually filled
    example_answers = {
        "Fruits": {
            "A": "Apple", "B": "Banana", "C": "Cherry", "D": "Date", "E": "Elderberry", "F": "Fig", "G": "Grape",
            "H": "Honeydew", "I": "Indian Fig", "J": "Jackfruit", "K": "Kiwi", "L": "Lemon", "M": "Mango", "N": "Nectarine",
            "O": "Orange", "P": "Papaya", "Q": "Quince", "R": "Raspberry", "S": "Strawberry", "T": "Tangerine", "U": "Ugli fruit",
            "V": "Vanilla", "W": "Watermelon", "X": "Xigua", "Y": "Yellow Passion Fruit", "Z": "Zucchini"
        },
        "Vegetables": {
            "A": "Artichoke", "B": "Broccoli", "C": "Carrot", "D": "Daikon", "E": "Endive", "F": "Fennel", "G": "Garlic",
            "H": "Horseradish", "I": "Iceberg Lettuce", "J": "Jalapeno", "K": "Kale", "L": "Leek", "M": "Mushroom", "N": "Napa Cabbage",
            "O": "Onion", "P": "Pepper", "Q": "Quinoa", "R": "Radish", "S": "Spinach", "T": "Tomato", "U": "Ulluco",
            "V": "Vine Leaf", "W": "Watercress", "X": "Xanthan Gum", "Y": "Yam", "Z": "Zucchini"
        },
        "Animals": {
            "A": "Antelope", "B": "Baboon", "C": "Cat", "D": "Dog", "E": "Elephant", "F": "Frog", "G": "Giraffe",
            "H": "Horse", "I": "Iguana", "J": "Jaguar", "K": "Kangaroo", "L": "Lion", "M": "Monkey", "N": "Newt",
            "O": "Ostrich", "P": "Penguin", "Q": "Quail", "R": "Rabbit", "S": "Snake", "T": "Tiger", "U": "Urial",
            "V": "Vulture", "W": "Wolf", "X": "Xerus", "Y": "Yak", "Z": "Zebra"
        },
        "Countries": {
            "A": "Argentina", "B": "Brazil", "C": "Canada", "D": "Denmark", "E": "Egypt", "F": "France", "G": "Germany",
            "H": "Hungary", "I": "India", "J": "Japan", "K": "Kenya", "L": "Luxembourg", "M": "Mexico", "N": "Netherlands",
            "O": "Oman", "P": "Portugal", "Q": "Qatar", "R": "Romania", "S": "Spain", "T": "Turkey", "U": "Ukraine",
            "V": "Vietnam", "W": "Wales", "X": "None", "Y": "Yemen", "Z": "Zimbabwe"
        },
        "Cities": {
            "A": "Amsterdam", "B": "Berlin", "C": "Copenhagen", "D": "Dubai", "E": "Edinburgh", "F": "Florence", "G": "Geneva",
            "H": "Helsinki", "I": "Istanbul", "J": "Jerusalem", "K": "Kyoto", "L": "Lisbon", "M": "Madrid", "N": "Nairobi",
            "O": "Oslo", "P": "Paris", "Q": "Quebec", "R": "Rome", "S": "Sydney", "T": "Tokyo", "U": "Utrecht",
            "V": "Vienna", "W": "Warsaw", "X": "Xenia", "Y": "York", "Z": "Zurich"
        },
        "Famous People": {
            "A": "Albert Einstein", "B": "Barack Obama", "C": "Charlie Chaplin", "D": "Diana Ross", "E": "Elvis Presley", 
            "F": "Freddie Mercury", "G": "Galileo Galilei", "H": "Helen Keller", "I": "Isaac Newton", "J": "J.K. Rowling",
            "K": "Kurt Cobain", "L": "Leonardo da Vinci", "M": "Marilyn Monroe", "N": "Nelson Mandela", "O": "Oprah Winfrey",
            "P": "Pablo Picasso", "Q": "Quentin Tarantino", "R": "Rosa Parks", "S": "Steve Jobs", "T": "Thomas Edison", 
            "U": "Usain Bolt", "V": "Vincent van Gogh", "W": "Walt Disney", "X": "Xavier Dolan", "Y": "Yoko Ono", "Z": "Zoe Saldana"
        },
        "Colors": {
            "A": "Amber", "B": "Blue", "C": "Cyan", "D": "Dandelion", "E": "Emerald", "F": "Fuchsia", "G": "Gold",
            "H": "Honey", "I": "Ivory", "J": "Jade", "K": "Khaki", "L": "Lavender", "M": "Magenta", "N": "Navy",
            "O": "Olive", "P": "Peach", "Q": "Quartz", "R": "Red", "S": "Silver", "T": "Turquoise", "U": "Ultramarine",
            "V": "Violet", "W": "White", "X": "Xanthous", "Y": "Yellow", "Z": "Zaffre"
        },
        "Sports": {
            "A": "Archery", "B": "Baseball", "C": "Cricket", "D": "Diving", "E": "Equestrian", "F": "Fencing", "G": "Golf",
            "H": "Hockey", "I": "Ice Skating", "J": "Judo", "K": "Karate", "L": "Lacrosse", "M": "Martial Arts", "N": "Netball",
            "O": "Orienteering", "P": "Polo", "Q": "Quidditch", "R": "Rugby", "S": "Soccer", "T": "Tennis", "U": "Ultimate Frisbee",
            "V": "Volleyball", "W": "Wrestling", "X": "XC Mountain Biking", "Y": "Yoga", "Z": "Zumba"
        },
        "Clothing": {
            "A": "Anorak", "B": "Blouse", "C": "Coat", "D": "Dress", "E": "Earmuffs", "F": "Frock", "G": "Gloves",
            "H": "Hat", "I": "Infinity Scarf", "J": "Jacket", "K": "Kimono", "L": "Leggings", "M": "Mittens", "N": "Nightgown",
            "O": "Overalls", "P": "Pajamas", "Q": "Quilted Jacket", "R": "Robe", "S": "Shirt", "T": "Trousers", "U": "Underwear",
            "V": "Vest", "W": "Waistcoat", "X": "None", "Y": "Yukata", "Z": "Zoot Suit"
        },
        "Food": {
            "A": "Apple Pie", "B": "Bread", "C": "Cheese", "D": "Donut", "E": "Egg", "F": "Fish", "G": "Grapes",
            "H": "Hamburger", "I": "Ice Cream", "J": "Jelly", "K": "Kale", "L": "Lasagna", "M": "Meatloaf", "N": "Noodles",
            "O": "Omelette", "P": "Pizza", "Q": "Quiche", "R": "Ramen", "S": "Steak", "T": "Taco", "U": "Udon",
            "V": "Venison", "W": "Waffles", "X": "Xacuti", "Y": "Yogurt", "Z": "Ziti"
        },
        "Drinks": {
            "A": "Apple Juice", "B": "Beer", "C": "Coffee", "D": "Daiquiri", "E": "Eggnog", "F": "Fanta", "G": "Ginger Ale",
            "H": "Hot Chocolate", "I": "Iced Tea", "J": "Juice", "K": "Kombucha", "L": "Lemonade", "M": "Milk", "N": "Negroni",
            "O": "Orange Juice", "P": "Punch", "Q": "Quik", "R": "Rum", "S": "Soda", "T": "Tea", "U": "Umeshu",
            "V": "Vodka", "W": "Whiskey", "X": "None", "Y": "Yoo-hoo", "Z": "Zinfandel"
        },
        "Tools": {
            "A": "Axe", "B": "Bolt Cutter", "C": "Chisel", "D": "Drill", "E": "Edger", "F": "File", "G": "Grinder",
            "H": "Hammer", "I": "Impact Driver", "J": "Jigsaw", "K": "Knife", "L": "Level", "M": "Mallet", "N": "Nail Gun",
            "O": "Oscillating Tool", "P": "Pliers", "Q": "Quick Clamp", "R": "Ratchet", "S": "Saw", "T": "Tape Measure",
            "U": "Utility Knife", "V": "Vise", "W": "Wrench", "X": "None", "Y": "Yardstick", "Z": "Zipper Tool"
        },
        "Flowers": {
            "A": "Aster", "B": "Begonia", "C": "Carnation", "D": "Daisy", "E": "Edelweiss", "F": "Freesia", "G": "Geranium",
            "H": "Hydrangea", "I": "Iris", "J": "Jasmine", "K": "Kalanchoe", "L": "Lavender", "M": "Marigold", "N": "Narcissus",
            "O": "Orchid", "P": "Peony", "Q": "Queen Anne's Lace", "R": "Rose", "S": "Sunflower", "T": "Tulip", "U": "Ursinia",
            "V": "Violet", "W": "Wisteria", "X": "None", "Y": "Yarrow", "Z": "Zinnia"
        },
        "Movies": {
            "A": "Avatar", "B": "Batman", "C": "Casablanca", "D": "Die Hard", "E": "E.T.", "F": "Forrest Gump", "G": "Gladiator",
            "H": "Harry Potter", "I": "Inception", "J": "Jaws", "K": "King Kong", "L": "Lion King", "M": "Matrix", "N": "No Country for Old Men",
            "O": "Ocean's Eleven", "P": "Pulp Fiction", "Q": "Quantum of Solace", "R": "Rocky", "S": "Star Wars", "T": "Titanic",
            "U": "Up", "V": "Vertigo", "W": "Wizard of Oz", "X": "X-Men", "Y": "You Only Live Twice", "Z": "Zootopia"
        },
        "Books": {
            "A": "Animal Farm", "B": "Brave New World", "C": "Catch-22", "D": "Dracula", "E": "Emma", "F": "Frankenstein", "G": "Great Expectations",
            "H": "Harry Potter", "I": "Invisible Man", "J": "Jane Eyre", "K": "Kite Runner", "L": "Les Miserables", "M": "Moby Dick", "N": "1984",
            "O": "Oliver Twist", "P": "Pride and Prejudice", "Q": "Quiet", "R": "Romeo and Juliet", "S": "Slaughterhouse-Five", "T": "To Kill a Mockingbird",
            "U": "Ulysses", "V": "Vanity Fair", "W": "War and Peace", "X": "None", "Y": "Young Goodman Brown", "Z": "Zorba the Greek"
        },
        "Songs": {
            "A": "All You Need Is Love", "B": "Bohemian Rhapsody", "C": "Come Together", "D": "Don't Stop Believin'", "E": "Every Breath You Take", 
            "F": "Firework", "G": "Good Vibrations", "H": "Hotel California", "I": "Imagine", "J": "Jailhouse Rock", "K": "Killing Me Softly", 
            "L": "Let It Be", "M": "My Way", "N": "No Woman, No Cry", "O": "One", "P": "Purple Rain", "Q": "Que Sera, Sera", "R": "Respect", 
            "S": "Stairway to Heaven", "T": "Thriller", "U": "Uptown Funk", "V": "Viva La Vida", "W": "Wonderwall", "X": "Xoxoxo", "Y": "Yesterday", "Z": "Zombie"
        },
        "TV Shows": {
            "A": "Arrested Development", "B": "Breaking Bad", "C": "Cheers", "D": "Dexter", "E": "ER", "F": "Friends", "G": "Game of Thrones",
            "H": "House", "I": "I Love Lucy", "J": "JAG", "K": "Knight Rider", "L": "Lost", "M": "Mad Men", "N": "Narcos",
            "O": "Oz", "P": "Parks and Recreation", "Q": "Quantico", "R": "Revenge", "S": "Stranger Things", "T": "The Simpsons",
            "U": "Under the Dome", "V": "Vikings", "W": "Westworld", "X": "X-Files", "Y": "Yellowstone", "Z": "Z Nation"
        },
        "Brands": {
            "A": "Apple", "B": "BMW", "C": "Coca-Cola", "D": "Disney", "E": "eBay", "F": "Ford", "G": "Google",
            "H": "Honda", "I": "IBM", "J": "Jaguar", "K": "Kellogg's", "L": "Lego", "M": "Microsoft", "N": "Nike",
            "O": "Oreo", "P": "Pepsi", "Q": "Quaker", "R": "Rolex", "S": "Samsung", "T": "Toyota", "U": "Uber",
            "V": "Visa", "W": "Walmart", "X": "Xerox", "Y": "Yahoo", "Z": "Zara"
        },
        "Transport": {
            "A": "Airplane", "B": "Bicycle", "C": "Car", "D": "Drone", "E": "Electric Scooter", "F": "Ferry", "G": "Glider",
            "H": "Helicopter", "I": "Icebreaker", "J": "Jet", "K": "Kayak", "L": "Limousine", "M": "Motorcycle", "N": "Narrowboat",
            "O": "Omnibus", "P": "Plane", "Q": "Quad Bike", "R": "Rickshaw", "S": "Subway", "T": "Train", "U": "Unicycle",
            "V": "Van", "W": "Wheelchair", "X": "None", "Y": "Yacht", "Z": "Zeppelin"
        },
        "Jobs": {
            "A": "Actor", "B": "Baker", "C": "Carpenter", "D": "Doctor", "E": "Engineer", "F": "Farmer", "G": "Gardener",
            "H": "Hairdresser", "I": "Illustrator", "J": "Journalist", "K": "King", "L": "Lawyer", "M": "Musician", "N": "Nurse",
            "O": "Optician", "P": "Pilot", "Q": "Quantity Surveyor", "R": "Radiologist", "S": "Scientist", "T": "Teacher",
            "U": "Urologist", "V": "Veterinarian", "W": "Writer", "X": "X-ray Technician", "Y": "Yacht Captain", "Z": "Zoologist"
        }
    }
    
    #initialize return string
    generated_answers = ""
    
    #iterates through the 5 selected categories
    for category in selected_categories:
        #first gets the dictionary of the category and then the letter within that category
        #included default situations where the category or letter couldn't be found
        answer = example_answers.get(category, {}).get(letter, "None")
        #adds the output to the return string in the form of category: answer
        generated_answers += f"{category}: {answer}\n"
    
    return generated_answers

def scattergories():
    print("Welcome to Scattergories!")
    selected_categories = get_categories()
    letter = input("Enter a letter (A-Z): ").strip().upper()
    
    if letter.isalpha() and len(letter) == 1:
        generated_answers = generate_answers(selected_categories, letter)
        print("\nGenerated Answers:")
        print(generated_answers)
    else:
        print("Invalid letter. Please enter a single letter from A to Z.")

if __name__ == "__main__":
    scattergories()
# Out:
# Welcome to Scattergories!
# Here are the available categories:
# 1. Fruits
# 2. Vegetables
# 3. Animals
# 4. Countries
# 5. Cities
# 6. Famous People
# 7. Colors
# 8. Sports
# 9. Clothing
# 10. Food
# 11. Drinks
# 12. Tools
# 13. Flowers
# 14. Movies
# 15. Books
# 16. Songs
# 17. TV Shows
# 18. Brands
# 19. Transport
# 20. Jobs
# Select category 1 (1-20): 1
# Select category 2 (1-20): 8
# Select category 3 (1-20): 15
# Select category 4 (1-20): 7
# Select category 5 (1-20): 20
# Enter a letter (A-Z): k
#
# Generated Answers:
# Fruits: Kiwi
# Sports: Karate
# Books: Kite Runner
# Colors: Khaki
# Jobs: King
